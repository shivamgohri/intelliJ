# %%
import cv2
import numpy
import time
from google.colab.patches import cv2_imshow
def detect_weed():
    img = cv2.imread('/content/drive/My Drive/weed3.PNG')
    cv2_imshow(img)
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    cv2_imshow(gray_image)           
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    cv2_imshow(hsv)
    mask = cv2.inRange(hsv,(36, 0, 0), (86, 255, 255) )
    cv2_imshow(mask)
    arr = numpy.ones([5,5],numpy.uint8)
    img_erosion = cv2.erode(mask, arr, iterations=1)
    cv2_imshow(img_erosion)
    img_dilation = cv2.dilate(img_erosion, arr, iterations=1)
    n_white_pix = numpy.sum(img_dilation == 255)
    print('Number of white pixels:', n_white_pix)
    if n_white_pix >= 10000:
        asd=1
    else:
        asd=0
    return asd

# %%
x = detect_weed(); time.sleep(3)
y=detect_weed(); time.sleep(3)
suma=x+y

if suma>=1:
  print(1)
else:
  print(0)
print("task completed")
# Out:
# <PIL.Image.Image image mode=RGB size=361x218 at 0x7F3872F220F0>
# <PIL.Image.Image image mode=L size=361x218 at 0x7F3872F22588>
# <PIL.Image.Image image mode=RGB size=361x218 at 0x7F3872F22518>
# <PIL.Image.Image image mode=L size=361x218 at 0x7F3872F22470>
# <PIL.Image.Image image mode=L size=361x218 at 0x7F3872F22518>
# Number of white pixels: 41187
# <PIL.Image.Image image mode=RGB size=361x218 at 0x7F3872F226A0>
# <PIL.Image.Image image mode=L size=361x218 at 0x7F3872F220F0>
# <PIL.Image.Image image mode=RGB size=361x218 at 0x7F3872F22198>
# <PIL.Image.Image image mode=L size=361x218 at 0x7F3872F22518>
# <PIL.Image.Image image mode=L size=361x218 at 0x7F3872F22470>
# Number of white pixels: 41187
# 1
# task completed
